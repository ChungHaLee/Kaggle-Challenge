# %% [markdown]
# # Kaggle Challenge
# ## #1 Titanic. Deep Learning from Disaster (with Keras)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# EDA 를 통해 데이터의 전반적인 연관성과 데이터의 특성을 파악했으므로, 이제 데이터가 Keras 모델에 들어가 정확도를 높일 수 있도록 데이터를 가공해야한다. 그리고 이 작업은 Train Data 와 Test Data 모두에 대해서 진행해야 한다.

# %% [markdown]
# ## 데이터 가공하기 (Preprocessing)

# %% [markdown]
# ### (1) Train Data 불러오기

# %%
raw_train = pd.read_csv('/home/lifeofpy/Desktop/Titanic/train.csv', engine='python')
raw_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### (2) Test Data 불러오기

# %%
raw_test = pd.read_csv('/home/lifeofpy/Desktop/Titanic/test.csv', engine='python')
raw_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### (3) 데이터 전체 상황 파악하기

# %%
raw_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
raw_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# train 과 test 데이터 모두 Age(나이)와 Cabin(좌석번호), Embarked(선착장) 데이터에 대해 결측치가 있으므로, 이에 대한 처리가 필요하다. 나이 데이터는 매우 중요하고 평균값으로 대체할 수 있는데에 비해, 좌석 데이터는 Pclass(승객등급) 데이터가 있고, 임의로 대체 불가하다고 생각해서 제외시키기로 했다. 그리고 선착장 변수는 결측치가 2개이므로, 가장 많이 나온 선착장으로 대체해준다.

# %% [markdown]
# 그리고 결측치는 없으나 해당 데이터에서 중요하지 않다고 판단한 Ticket(티켓번호) 데이터와 Fare(요금) 데이터에 대한 열을 삭제해준다.

# %%
del raw_train['Ticket']
del raw_test['Ticket']
del raw_train['Fare']
del raw_test['Fare']

# %% [markdown]
# ### (4) 중요하지 않은 Cabin 데이터 열 삭제하기

# %%
del raw_train['Cabin']

# %%
raw_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch Embarked
# 0        0        S
# 1        0        C
# 2        0        S
# 3        0        S
# 4        0        S
# ..     ...      ...
# 886      0        S
# 887      0        S
# 888      2        S
# 889      0        C
# 890      0        Q
#
# [891 rows x 9 columns]

# %%
del raw_test['Cabin']

# %%
raw_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch Embarked
# 0      male  34.5      0      0        Q
# 1    female  47.0      1      0        S
# 2      male  62.0      0      0        Q
# 3      male  27.0      0      0        S
# 4    female  22.0      1      1        S
# ..      ...   ...    ...    ...      ...
# 413    male   NaN      0      0        S
# 414  female  39.0      0      0        C
# 415    male  38.5      0      0        S
# 416    male   NaN      0      0        S
# 417    male   NaN      1      1        C
#
# [418 rows x 8 columns]

# %% [markdown]
# ### (5) Age 데이터 나이 평균으로 결측치 채워넣기

# %%
raw_train['Age'].fillna(value=round(raw_train['Age'].mean(), 1), inplace=True)

# %%
raw_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.7      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch Embarked
# 0        0        S
# 1        0        C
# 2        0        S
# 3        0        S
# 4        0        S
# ..     ...      ...
# 886      0        S
# 887      0        S
# 888      2        S
# 889      0        C
# 890      0        Q
#
# [891 rows x 9 columns]

# %%
raw_test['Age'].fillna(value=round(raw_test['Age'].mean(), 1), inplace=True)

# %%
raw_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch Embarked
# 0      male  34.5      0      0        Q
# 1    female  47.0      1      0        S
# 2      male  62.0      0      0        Q
# 3      male  27.0      0      0        S
# 4    female  22.0      1      1        S
# ..      ...   ...    ...    ...      ...
# 413    male  30.3      0      0        S
# 414  female  39.0      0      0        C
# 415    male  38.5      0      0        S
# 416    male  30.3      0      0        S
# 417    male  30.3      1      1        C
#
# [418 rows x 8 columns]

# %% [markdown]
# ### (6) Embarked 변수의 결측치를 가장 많이 나온 선착장으로 대체하기

# %%
raw_train['Embarked'].fillna(value='S', inplace=True)

# %%
raw_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.7      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch Embarked
# 0        0        S
# 1        0        C
# 2        0        S
# 3        0        S
# 4        0        S
# ..     ...      ...
# 886      0        S
# 887      0        S
# 888      2        S
# 889      0        C
# 890      0        Q
#
# [891 rows x 9 columns]

# %% [markdown]
# ## 특징변수 새로 만들기 (Making Features)

# %% [markdown]
# ### (1) 호칭을 나타내는 Title 데이터

# %% [markdown]
# Name 데이터는 해당 승객이 귀족인지 아닌지를 판별해주며, 나이대를 대충 가늠하게 할 수 있는 중요한 데이터이다.

# %%
raw_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch Embarked
# 0      0        S
# 1      0        C
# 2      0        S
# 3      0        S
# 4      0        S

# %% [markdown]
# 이렇게 이름에 Mr, Mrs, Miss 등 어떤 호칭이 붙는지에 따라서 생존에 영향을 끼쳤을 수 있으므로, Title 이라는 변수를 따로 만들어 호칭만 따로 볼 수 있도록 할 것이다.

# %% [markdown]
# 따라서 Name 변수에서 호칭만 따로 떼오는 정규식을 활용해 호칭만 'Title' 변수의 값으로 만들었다.

# %%
raw_train['Title'] = raw_train.Name.str.extract('([A-Za-z]+)\.', expand=False)

# %%
raw_train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Don           1
# Mme           1
# Jonkheer      1
# Ms            1
# Sir           1
# Capt          1
# Lady          1
# Countess      1
# Name: Title, dtype: int64

# %% [markdown]
# 아래와 같은 타이틀이 있는데, 이 타이틀 모두가 필요한 것은 아니므로, 거의 나타나지 않는(Mr, Miss, Mrs, Master 가 아닌) 호칭을 통합해야 한다.

# %%
raw_train['Title'] = raw_train['Title'].replace(['Countess','Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

# %%
raw_train['Title'] = raw_train['Title'].replace('Lady', 'Mrs')
raw_train['Title'] = raw_train['Title'].replace('Mme', 'Mrs')
raw_train['Title'] = raw_train['Title'].replace('Mlle', 'Miss')
raw_train['Title'] = raw_train['Title'].replace('Ms', 'Miss')

# %% [markdown]
# 이렇게 통합을 해주었으므로, Title 변수가 효과가 있는지 확인해보도록 한다.

# %%
sns.barplot(x='Title', y='Survived', data=raw_train)
# Out:
# <AxesSubplot:xlabel='Title', ylabel='Survived'>

# %% [markdown]
# 남성(Mr)은 거의 살아남지 못했으나, Master 타이틀을 가지고 있는 귀족은 생존율이 60%에 가까웠다.

# %% [markdown]
# 이러한 값들을 모델에 넣기 위해 숫자 형태로 만들어야 한다. 따라서 unique 함수를 통해 Mr, Mrs, Miss, Master, Rare 에 대한 값을 0,1,2,3,4 에 대한 숫자로 표현한다. unique 함수는 중복되지 않는 고유한 요소들의 배열을 리턴해준다.

# %%
_, raw_train['Title'] = np.unique(raw_train['Title'], return_inverse=True)

# %% [markdown]
# 여기서 파라미터인 return_inverse 는 값이 True 이면 입력 배열을 재구성할 때 쓰이는 고유 배열의 인덱스를 반환한다.

# %%
raw_train['Title'].head(10)
# Out:
# 0    2
# 1    3
# 2    1
# 3    3
# 4    2
# 5    2
# 6    2
# 7    0
# 8    3
# 9    3
# Name: Title, dtype: int64

# %% [markdown]
# ### (2) 나이가 어린 승객을 구분해주는 young_survivors 데이터

# %%
raw_train['young_survivors'] = 0
raw_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch Embarked  Title  young_survivors
# 0      0        S      2                0
# 1      0        C      3                0
# 2      0        S      1                0
# 3      0        S      3                0
# 4      0        S      2                0

# %% [markdown]
# '나이가 어리다'의 기준을 10대 이하로 잡아보자. 그리고 나이가 어린(13살 이하) 생존자라는 파생변수(young_survivors)를 하나 만들어서, 나이가 어린 생존자의 비율과 그렇지 않은 생존자의 비율을 비교해보자.

# %%
young_people = 0
for i in range(len(raw_train)):
    if raw_train['Age'][i] <= 13:
        young_people += 1
        if raw_train['Survived'][i] == 1:
            raw_train['young_survivors'][i] += 1
raw_train[30:60]
# Out:
# /home/lifeofpy/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     PassengerId  Survived  Pclass  \
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# 41           42         0       2
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
# 50           51         0       3
# 51           52         0       3
# 52           53         1       1
# 53           54         1       2
# 54           55         0       1
# 55           56         1       1
# 56           57         1       2
# 57           58         0       3
# 58           59         1       2
# 59           60         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  29.7      1
# 32                           Glynn, Miss. Mary Agatha  female  29.7      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 36                                   Mamee, Mr. Hanna    male  29.7      0
# 37                           Cann, Mr. Ernest Charles    male  21.0      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.0      2
# 39                        Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 42                                Kraeff, Mr. Theodor    male  29.7      0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 45                           Rogers, Mr. William John    male  29.7      0
# 46                                  Lennon, Mr. Denis    male  29.7      1
# 47                          O'Driscoll, Miss. Bridget  female  29.7      0
# 48                                Samaan, Mr. Youssef    male  29.7      2
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 50                         Panula, Master. Juha Niilo    male   7.0      4
# 51                       Nosworthy, Mr. Richard Cater    male  21.0      0
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 55                                  Woolner, Mr. Hugh    male  29.7      0
# 56                                  Rugg, Miss. Emily  female  21.0      0
# 57                                Novel, Mr. Mansouer    male  28.5      0
# 58                       West, Miss. Constance Mirium  female   5.0      1
# 59                 Goodwin, Master. William Frederick    male  11.0      5
#
#     Parch Embarked  Title  young_survivors
# 30      0        C      4                0
# 31      0        C      3                0
# 32      0        Q      1                0
# 33      0        S      2                0
# 34      0        C      2                0
# 35      0        S      2                0
# 36      0        C      2                0
# 37      0        S      2                0
# 38      0        S      1                0
# 39      0        C      1                0
# 40      0        S      3                0
# 41      0        S      3                0
# 42      0        C      2                0
# 43      2        C      1                1
# 44      0        Q      1                0
# 45      0        S      2                0
# 46      0        Q      2                0
# 47      0        Q      1                0
# 48      0        C      2                0
# 49      0        S      3                0
# 50      1        S      0                0
# 51      0        S      2                0
# 52      0        C      3                0
# 53      0        S      3                0
# 54      1        C      2                0
# 55      0        S      2                0
# 56      0        S      1                0
# 57      0        C      2                0
# 58      2        S      1                1
# 59      2        S      0                0

# %% [markdown]
# ### (3) 그 외 변수 정리해주기

# %% [markdown]
# 분석에 필요없는 변수는 모델에 불필요하므로 삭제한다.

# %%
raw_train.drop(['SibSp', 'Parch', 'Name', 'PassengerId', 'Age'], inplace=True, axis=1)

# %% [markdown]
# 분석에 필요한 나머지 변수들을 모델에 넣기 위해 숫자로 바꿔준다.

# %%
_, raw_train['Sex'] = np.unique(raw_train['Sex'], return_inverse=True)

# %%
_, raw_train['Embarked'] = np.unique(raw_train['Embarked'], return_inverse=True)

# %% [markdown]
# 이렇게 모델이 넣을 모든 변수를 숫자로 바꾸었다. train data 의 값을 확인해보면 다음과 같다.

# %%
raw_train.head(10)
# Out:
#    Pclass  Sex  Embarked  Title  young_survivors
# 0       3    1         2      2                0
# 1       1    0         0      3                0
# 2       3    0         2      1                0
# 3       1    0         2      3                0
# 4       3    1         2      2                0
# 5       3    1         1      2                0
# 6       1    1         2      2                0
# 7       3    1         2      0                0
# 8       3    0         2      3                0
# 9       2    0         0      3                0

# %% [markdown]
# 이제 목표변수를 독립변수와 분리해준다. 목표변수인 생존여부를 raw_train_y 로 구분했다.

# %%
raw_train_y = np.ravel(raw_train.Survived)
raw_train.drop(['Survived'], inplace=True, axis=1)

# %% [markdown]
# ## Keras 모델 준비하기

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(5,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# train data 에 대해 학습을 시작한다. 최적화 함수는 adam, 오차 함수는 이진분류이기 때문에 binary cross entropy 함수를 사용했다. 그리고 정확도를 지표로 삼는다.

# %%
model.fit(raw_train, raw_train_y, epochs=50, batch_size=1, verbose=1)
# Out:
# Epoch 1/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7116
# Epoch 2/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4479 - accuracy: 0.8081
# Epoch 3/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4278 - accuracy: 0.8092
# Epoch 4/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4156 - accuracy: 0.8272
# Epoch 5/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4120 - accuracy: 0.8249
# Epoch 6/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4064 - accuracy: 0.8249
# Epoch 7/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4029 - accuracy: 0.8328
# Epoch 8/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4023 - accuracy: 0.8249
# Epoch 9/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3997 - accuracy: 0.8272
# Epoch 10/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4006 - accuracy: 0.8373
# Epoch 11/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3968 - accuracy: 0.8384
# Epoch 12/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3989 - accuracy: 0.8283
# Epoch 13/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3942 - accuracy: 0.8440
# Epoch 14/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3951 - accuracy: 0.8395
# Epoch 15/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3956 - accuracy: 0.8361
# Epoch 16/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3926 - accuracy: 0.8429
# Epoch 17/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3953 - accuracy: 0.8350
# Epoch 18/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3932 - accuracy: 0.8395
# Epoch 19/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3943 - accuracy: 0.8339
# Epoch 20/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3931 - accuracy: 0.8418
# Epoch 21/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3939 - accuracy: 0.8384
# Epoch 22/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3912 - accuracy: 0.8429
# Epoch 23/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3893 - accuracy: 0.8395
# Epoch 24/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3922 - accuracy: 0.8418
# Epoch 25/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3888 - accuracy: 0.8451
# Epoch 26/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3911 - accuracy: 0.8406
# Epoch 27/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3905 - accuracy: 0.8418
# Epoch 28/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3882 - accuracy: 0.8418
# Epoch 29/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3886 - accuracy: 0.8418
# Epoch 30/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3889 - accuracy: 0.8440
# Epoch 31/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3895 - accuracy: 0.8373
# Epoch 32/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3889 - accuracy: 0.8373
# Epoch 33/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3866 - accuracy: 0.8350
# Epoch 34/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3881 - accuracy: 0.8395
# Epoch 35/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3898 - accuracy: 0.8361
# Epoch 36/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3879 - accuracy: 0.8350
# Epoch 37/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3884 - accuracy: 0.8361
# Epoch 38/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3871 - accuracy: 0.8429
# Epoch 39/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3855 - accuracy: 0.8395
# Epoch 40/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3877 - accuracy: 0.8406
# Epoch 41/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3896 - accuracy: 0.8350
# Epoch 42/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3894 - accuracy: 0.8395
# Epoch 43/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3865 - accuracy: 0.8418
# Epoch 44/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3881 - accuracy: 0.8418
# Epoch 45/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3855 - accuracy: 0.8395
# Epoch 46/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3871 - accuracy: 0.8395
# Epoch 47/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3876 - accuracy: 0.8361
# Epoch 48/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3826 - accuracy: 0.8451
# Epoch 49/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3858 - accuracy: 0.8440
# Epoch 50/50
# 891/891 [==============================] - 1s 1ms/step - loss: 0.3872 - accuracy: 0.8373

# %% [markdown]
# 이렇게 train data 에 대해 학습을 마쳤다. 정확도는 83.73%가 나왔다. 이제 test data 에 대해 잘 학습이 되었는지 평가를 시작해야 한다. 따라서 test dataset 을 train data 를 준비했던 것과 같은 방법으로 준비해준다.

# %% [markdown]
# ### 1) Title 데이터 정제하기

# %%
to_test = raw_test.copy(True)
to_test['Title'] = to_test.Name.str.extract('([A-Za-z]+)\.', expand=False)
to_test['Title'] = to_test['Title'].replace(['Countess','Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

# %%
to_test['Title'] = to_test['Title'].replace('Mlle', 'Miss')
to_test['Title'] = to_test['Title'].replace('Ms', 'Miss')
to_test['Title'] = to_test['Title'].replace('Mme', 'Mrs')
to_test['Title'] = to_test['Title'].replace('Lady', 'Mrs')

# %%
to_test['Title']
# Out:
# 0          Mr
# 1         Mrs
# 2          Mr
# 3          Mr
# 4         Mrs
#         ...
# 413        Mr
# 414      Rare
# 415        Mr
# 416        Mr
# 417    Master
# Name: Title, Length: 418, dtype: object

# %%
_, to_test['Title'] = np.unique(to_test['Title'], return_inverse=True)

# %% [markdown]
# ### 2) young_survivors 데이터 추가하기

# %%
to_test['young'] = 0
to_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch Embarked  Title  young
# 0  34.5      0      0        Q      2      0
# 1  47.0      1      0        S      3      0
# 2  62.0      0      0        Q      2      0
# 3  27.0      0      0        S      2      0
# 4  22.0      1      1        S      3      0

# %%
for i in range(len(to_test)):
    if to_test['Age'][i] <= 13:
        to_test['young'][i] += 1
to_test[50:60]
# Out:
# /home/lifeofpy/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     PassengerId  Pclass                               Name     Sex   Age  \
# 50          942       1           Smith, Mr. Lucien Philip    male  24.0
# 51          943       2                 Pulbaum, Mr. Franz    male  27.0
# 52          944       2      Hocking, Miss. Ellen Nellie""  female  20.0
# 53          945       1         Fortune, Miss. Ethel Flora  female  28.0
# 54          946       2  Mangiavacchi, Mr. Serafino Emilio    male  30.3
# 55          947       3               Rice, Master. Albert    male  10.0
# 56          948       3                    Cor, Mr. Bartol    male  35.0
# 57          949       3      Abelseth, Mr. Olaus Jorgensen    male  25.0
# 58          950       3          Davison, Mr. Thomas Henry    male  30.3
# 59          951       1        Chaudanson, Miss. Victorine  female  36.0
#
#     SibSp  Parch Embarked  Title  young
# 50      1      0        S      2      0
# 51      0      0        C      2      0
# 52      2      1        S      1      0
# 53      3      2        S      1      0
# 54      0      0        C      2      0
# 55      4      1        Q      0      1
# 56      0      0        S      2      0
# 57      0      0        S      2      0
# 58      1      0        S      2      0
# 59      0      0        C      1      0

# %% [markdown]
# ### 3) 필요없는 데이터 삭제하기

# %%
to_test = to_test.drop(['SibSp', 'Parch', 'Name', 'PassengerId', 'Age'], axis=1)

# %%
_, to_test['Sex'] = np.unique(to_test['Sex'], return_inverse=True)

# %%
_, to_test['Embarked'] = np.unique(to_test['Embarked'], return_inverse=True)

# %%
to_test
# Out:
#      Pclass  Sex  Embarked  Title  young
# 0         3    1         1      2      0
# 1         3    0         2      3      0
# 2         2    1         1      2      0
# 3         3    1         2      2      0
# 4         3    0         2      3      0
# ..      ...  ...       ...    ...    ...
# 413       3    1         2      2      0
# 414       1    0         0      4      0
# 415       3    1         2      2      0
# 416       3    1         2      2      0
# 417       3    1         0      0      0
#
# [418 rows x 5 columns]

# %% [markdown]
# test dataset 또한 정제가 되었으므로, 이제 학습한 모델을 통해 예측을 시작한다. 예측을 더 쉽게 하기 위해 flatten(평탄화)를 진행한다.

# %%
predictions = model.predict_classes(to_test).flatten()
# Out:
# WARNING:tensorflow:From <ipython-input-99-46eeed505d2c>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
predictions[:5]
# Out:
# array([0, 1, 0, 0, 1], dtype=int32)

# %%
submission = pd.DataFrame({
    "PassengerId": raw_test["PassengerId"],
    "Survived": predictions
})
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ☞ 타이타닉 생존자 예측에 대해서 Keras 를 사용한 결과, train data 학습에 대해서 83.9%의 정확도를 보였고, test data 의 정확도는 76%가 나왔다. 이는 train data 의 수가 891개로 굉장히 적어서 딥러닝 모델에서 높은 정확도를 낼 수 없었다는 것을 나타낸다.
